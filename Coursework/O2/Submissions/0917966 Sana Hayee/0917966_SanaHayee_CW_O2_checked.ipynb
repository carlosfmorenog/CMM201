# %% [markdown]
# # Coursework Output 2
# *Instructions*: In this coursework, you will show your domain of the data related Python skills required for business analytics. To do so, you will use packages such as *numpy* and *matplotlib*.

# %% [markdown]
# ## Importing and Visualising a Dataset in Python
# Each student will be assigned a different dataset in a *comma separated value* (*.csv*) format. The main goal is to import such dataset into Python so that you can wrangle and visualise the data in better ways. This will allow you to get your own conclusions and start building up knowledge regarding on how you could potentially learn from data to predict or classify future instances.
#
# You must create a program which allows you to select from the following options:
# 1. Import and print your dataset into Python as a numpy array.
# 2. Query and print an instance of the dataset by row number or by id (i.e. first column of the table).
# 3. Create a "reduced" dataset (i.e. with less columns) by indicating a list of column names to bring upon this newly created dataset.
# 4. Plot the dataset by means of a scatterplot which relates two columns specified by the user. The plot has to show the $x$ and $y$ axis labels as the chosen columns, and use the *target/class* column (i.e. the last one) as the colour variable.
# 5. Exit the program.

# %% [markdown]
# ## Additional Considerations
# * The program has to check that every input is valid.
# * No option (except for exit) can be executed until option 1 is executed first.

# %% [markdown]
# ## Submission Instructions
#
# * Once that you have finished your program, run all cells and run the main program cell using the following sequence of options: 0(wrong option),2(has to fail),1,2(by row index),2(by row name),3,4,5.
# * Then, without clearing the kernel, generate a html **OR** pdf file from the Jupyter notebook.
# * Clear the Jupyter notebook kernel, then name both the Jupyter notebook and the html/pdf files with your id number and submit them to the corresponding Moodle's dropbox before **12th December, 2019**.

# %%
# !pip install pillow
# !pip install matplotlib
# !pip install scikit-image
# !pip install scikit-learn

# %%
### Use this cell to import all necessary packages
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv
from sklearn import datasets
from sklearn.linear_model import LinearRegression
pd.set_option('display.max_rows', 1000)

# %%
## Use this cell to define the function corresponding to OPTION 1
def option1(filename):
    '''With this function you import the dataset into a numpy array.'''
    data = pd.read_csv(filename)
    #pd.read_csv('countries.csv')
        #return pd.read_csv('countries.csv')
    return data
#option1('countries.csv')

# %%
## Use this cell to define the function corresponding to OPTION 2
def option2(data, rowmethod, rownumber):
    '''This function queries and prints a row of the dataset (by row number or id).'''
#print('Select the row number  to query')
#row = input(int)
#x=0
#while 0<row>142:
    #data=pd.read_csv(filename)
    #data = filename

    if rowmethod == 1:
        row = data.loc[rownumber] 
        print(row)
    elif rowmethod == 2:
        row = data.loc[data['country id'] == rownumber]
        print(row) 
#data = option1('countries.csv')        
#option2(data,2,107)

# %%
## Use this cell to define the function corresponding to OPTION 3
def option3(columnname, data, newdata):
    '''This function creates a new dataset by indicating which columns to include.'''

    #data = pd.read_csv(filename)
    data.head()
    #newdata = data[columnname].values
    newdata1=data[columnname].values
    newdata.append(newdata1)
#b=data['continent'].values
#data[['population','continent']]
    return newdata

#option3('country id','countries.csv')

# %%
# Use this cell to define the function corresponding to OPTION 4
def option4(xaxis,yaxis,target):
    '''This function visualises the dataset using a scatterplot.'''
#data.plot(kind='scatter', x='gdp_per_capita', y='population', c='continent', cmap='gnuplot2', title= 'GDP vs Population')
    data.plot(kind='scatter', x=xaxis, y=yaxis, c=target, cmap='gnuplot2', title= xaxis+' vs '+yaxis)

#data.plot.scatter(x='gdp_per_capita', y='population', c='continent')
    plt.show()

#option4('gdp_per_capita','population','continent')

# %%
## Use this cell to create the "main" part of your program
## Use this cell to create the "main" part of your program
print('Welcome to Sana Hayee AND 0917966 business case.')

options = []
newdata = []

x = True

while x:
    print('Welcome to my menu. Select an option (1,2,3,4,5):')
    x = input()
    options.append(x)
    
    if x == '1':
        data = option1('countries.csv')
        #option2(data,2,107)
        print(data)
        print ('Dataset has been imported!')   
    elif x == '2':
        if '1' in options:
            
            print('Select 1 to query by row number or 2 to query by row name:')
            rowmethod = int(input())
            while rowmethod not in [1,2]:
            
                    print('Option not valid')
                    print('Select 1 to query by row number or 2 to query by row name:')
                    rowmethod = int(input())
                    continue 
            
            if rowmethod == 1:
                print('Select the row number to query (indexes start in 0):')
                rownumber = int(input())
                while rownumber < 0 or rownumber > len(data):
            
                    print('Option not valid')
                    print('Select the row number to query (indexes start in 0):')
                    rownumber = int(input())
                    continue 
            
            elif rowmethod == 2:
                print('Select the row number to query:')
                rownumber = int(input())
                while rownumber not in data['country id'].values:
            
                    print('Option not valid')
                    print('Select the row number to query:')
                    rownumber = int(input())
                    continue 
                    
            rowdata = option2 (data, rowmethod, rownumber)
            print(rowdata)
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '3':
        if '1' in options:
            y = True
            while y:
                print('Indicate a column to include:')
                print(data.columns)
                columnname = input()
                if columnname not in data:
                    print('Column does not exists')
                    continue  
                        
                       
                #columnname = 'population'
                option3(columnname,data,newdata)
                print('Do you want to indicate another column? (Y/N)')           
                yn = input()
                if yn == 'N' or yn == 'n':
                    print(newdata)
                    break
                                
            
        else:
            print('The first option to be selected shall be 1. Please try again')
        # (students, marks) = option3()
    elif x == '4':
        if '1' in options:
            z = True
            xaxis = ''
            yaxis = ''
            while z:
                print('Select the variable to use as x axis:')
                print(data.columns)
                xaxis=input()
                while xaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as x axis:')
                    print(data.columns)
                    xaxis=input()
                    continue 
            
                print('Select the variable to use as y axis:')
                print(data.columns)
                yaxis=input()
                while yaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as y axis:')
                    print(data.columns)
                    yaxis=input()
                    continue 
                
                print('Select the variable to use as target:')
                print(data.columns)
                target=input()
                while target not in data:
                    print('Column does not exists')
                    print('Select the variable to use as target:')
                    print(data.columns)
                    target=input()
                    continue 
                    
                option4(xaxis,yaxis,target)
                break
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '5':
        
       
        break
    else:
        print('Wrong option. Please try again.')
# Out:
# Welcome to Sana Hayee AND 0917966 business case.
# Welcome to my menu. Select an option (1,2,3,4,5):
# ijij
# Wrong option. Please try again.
# Welcome to my menu. Select an option (1,2,3,4,5):
# 9999
# Wrong option. Please try again.
# Welcome to my menu. Select an option (1,2,3,4,5):
# 2

# Welcome to my menu. Select an option (1,2,3,4,5):
# 2
# Select 1 to query by row number or 2 to query by row name:
# 3
# Option not valid
# Select 1 to query by row number or 2 to query by row name:
# dxdf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d1e34d6b0e64> in <module>()
#      27                     print('Option not valid')
#      28                     print('Select 1 to query by row number or 2 to query by row name:')
# ---> 29                     rowmethod = int(input())
#      30                     continue
#      31
#
# ValueError: invalid literal for int() with base 10: 'dxdf'

# %% [markdown]
# **At this stage you didn't check that the input has to be a number, and thus the code crashed!**

# %%
## Use this cell to create the "main" part of your program
## Use this cell to create the "main" part of your program
print('Welcome to Sana Hayee AND 0917966 business case.')

options = []
newdata = []

x = True

while x:
    print('Welcome to my menu. Select an option (1,2,3,4,5):')
    x = input()
    options.append(x)
    
    if x == '1':
        data = option1('countries.csv')
        #option2(data,2,107)
        print(data)
        print ('Dataset has been imported!')   
    elif x == '2':
        if '1' in options:
            
            print('Select 1 to query by row number or 2 to query by row name:')
            rowmethod = int(input())
            while rowmethod not in [1,2]:
            
                    print('Option not valid')
                    print('Select 1 to query by row number or 2 to query by row name:')
                    rowmethod = int(input())
                    continue 
            
            if rowmethod == 1:
                print('Select the row number to query (indexes start in 0):')
                rownumber = int(input())
                while rownumber < 0 or rownumber > len(data):
            
                    print('Option not valid')
                    print('Select the row number to query (indexes start in 0):')
                    rownumber = int(input())
                    continue 
            
            elif rowmethod == 2:
                print('Select the row number to query:')
                rownumber = int(input())
                while rownumber not in data['country id'].values:
            
                    print('Option not valid')
                    print('Select the row number to query:')
                    rownumber = int(input())
                    continue 
                    
            rowdata = option2 (data, rowmethod, rownumber)
            print(rowdata)
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '3':
        if '1' in options:
            y = True
            while y:
                print('Indicate a column to include:')
                print(data.columns)
                columnname = input()
                if columnname not in data:
                    print('Column does not exists')
                    continue  
                        
                       
                #columnname = 'population'
                option3(columnname,data,newdata)
                print('Do you want to indicate another column? (Y/N)')           
                yn = input()
                if yn == 'N' or yn == 'n':
                    print(newdata)
                    break
                                
            
        else:
            print('The first option to be selected shall be 1. Please try again')
        # (students, marks) = option3()
    elif x == '4':
        if '1' in options:
            z = True
            xaxis = ''
            yaxis = ''
            while z:
                print('Select the variable to use as x axis:')
                print(data.columns)
                xaxis=input()
                while xaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as x axis:')
                    print(data.columns)
                    xaxis=input()
                    continue 
            
                print('Select the variable to use as y axis:')
                print(data.columns)
                yaxis=input()
                while yaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as y axis:')
                    print(data.columns)
                    yaxis=input()
                    continue 
                
                print('Select the variable to use as target:')
                print(data.columns)
                target=input()
                while target not in data:
                    print('Column does not exists')
                    print('Select the variable to use as target:')
                    print(data.columns)
                    target=input()
                    continue 
                    
                option4(xaxis,yaxis,target)
                break
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x ==

# Welcome to my menu. Select an option (1,2,3,4,5):
# 2
# Select 1 to query by row number or 2 to query by row name:
# 1
# Select the row number to query (indexes start in 0):
# -1
# Option not valid
# Select the row number to query (indexes start in 0):
# 142
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\foo\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# C:\ProgramData\Anaconda3\envs\foo\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [142] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d1e34d6b0e64> in <module>()
#      50                     continue
#      51
# ---> 52             rowdata = option2 (data, rowmethod, rownumber)
#      53             print(rowdata)
#      54         else:
#
# <ipython-input-4-e75ffd7df2e8> in option2(data, rowmethod, rownumber)
#      11
#      12     if rowmethod == 1:
# ---> 13         row = data.loc[rownumber]
#      14         print(row)
#      15     elif rowmethod == 2:
#
# C:\ProgramData\Anaconda3\envs\foo\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\envs\foo\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1624
#    1625         # fall thru to straight lookup
# -> 1626         self._has_valid_type(key, axis)
#    1627         return self._get_label(key, axis=axis)
#    1628
#
# C:\ProgramData\Anaconda3\envs\foo\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1512                 raise
#    1513             except:
# -> 1514                 error()
#    1515
#    1516         return True
#
# C:\ProgramData\Anaconda3\envs\foo\lib\site-packages\pandas\core\indexing.py in error()
#    1499                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#    1503             try:
#
# KeyError: 'the label [142] is not in the [index]'

# %% [markdown]
# **Here I queried for row 142 and the code crashed**

# %%
## Use this cell to create the "main" part of your program
## Use this cell to create the "main" part of your program
print('Welcome to Sana Hayee AND 0917966 business case.')

options = []
newdata = []

x = True

while x:
    print('Welcome to my menu. Select an option (1,2,3,4,5):')
    x = input()
    options.append(x)
    
    if x == '1':
        data = option1('countries.csv')
        #option2(data,2,107)
        print(data)
        print ('Dataset has been imported!')   
    elif x == '2':
        if '1' in options:
            
            print('Select 1 to query by row number or 2 to query by row name:')
            rowmethod = int(input())
            while rowmethod not in [1,2]:
            
                    print('Option not valid')
                    print('Select 1 to query by row number or 2 to query by row name:')
                    rowmethod = int(input())
                    continue 
            
            if rowmethod == 1:
                print('Select the row number to query (indexes start in 0):')
                rownumber = int(input())
                while rownumber < 0 or rownumber > len(data):
            
                    print('Option not valid')
                    print('Select the row number to query (indexes start in 0):')
                    rownumber = int(input())
                    continue 
            
            elif rowmethod == 2:
                print('Select the row number to query:')
                rownumber = int(input())
                while rownumber not in data['country id'].values:
            
                    print('Option not valid')
                    print('Select the row number to query:')
                    rownumber = int(input())
                    continue 
                    
            rowdata = option2 (data, rowmethod, rownumber)
            print(rowdata)
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '3':
        if '1' in options:
            y = True
            while y:
                print('Indicate a column to include:')
                print(data.columns)
                columnname = input()
                if columnname not in data:
                    print('Column does not exists')
                    continue  
                        
                       
                #columnname = 'population'
                option3(columnname,data,newdata)
                print('Do you want to indicate another column? (Y/N)')           
                yn = input()
                if yn == 'N' or yn == 'n':
                    print(newdata)
                    break
                                
            
        else:
            print('The first option to be selected shall be 1. Please try again')
        # (students, marks) = option3()
    elif x == '4':
        if '1' in options:
            z = True
            xaxis = ''
            yaxis = ''
            while z:
                print('Select the variable to use as x axis:')
                print(data.columns)
                xaxis=input()
                while xaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as x axis:')
                    print(data.columns)
                    xaxis=input()
                    continue 
            
                print('Select the variable to use as y axis:')
                print(data.columns)
                yaxis=input()
                while yaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as y axis:')
                    print(data.columns)
                    yaxis=input()
                    continue 
                
                print('Select the variable to use as target:')
                print(data.columns)
                target=input()
                while target not in data:
                    print('Column does not exists')
                    print('Select the variable to use as target:')
                    print(data.columns)
                    target=input()
                    continue 
                    
                option4(xaxis,yaxis,target)
                break
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '5':
        
       
        break
    else:
        print('Wrong option. Please try again.')
# Out:
# Welcome to Sana Hayee AND 0917966 business case.
# Welcome to my menu. Select an option (1,2,3,4,5):
# 1
#      country id  population  life_expectancy  gdp_per_capita  continent
# 0            11    31889923           43.828      974.580338          1
# 1            23     3600523           76.423     5937.029526          3
# 2            35    33333216           72.301     6223.367465          4
# 3            47    12420476           42.731     4797.231267          4
# 4            59    40301927           75.320    12779.379640          2
# 5            71    20434176           81.235    34435.367440          5
# 6            83     8199783           79.829    36126.492700          3
# 7            95      708573           75.635    29796.048340          1
# 8           107   150448339           64.062     1391.253792          1
# 9           119    10392226           79.441    33692.605080          3
# 10          131     8078314           56.728     1441.284873          4
# 11          143     9119152           65.554     3822.137084          2
# 12          155     4552198           74.852     7446.298803          3
# 13          167     1639131           50.728    12569.851770          4
# 14          179   190010647           72.390     9065.800825          2
# 15          191     7322858           73.005    10680.792820          3
# 16          203    14326203           52.295     1217.032994          4
# 17          215     8390505           49.580      430.070692          4
# 18          227    14131858           59.723     1713.778686          1
# 19          239    17696293           50.430     2042.095240          4
# 20          251    33390141           80.653    36319.235010          2
# 21          263     4369038           44.741      706.016537          4
# 22          275    10238807           50.651     1704.063724          4
# 23          287    16284741           78.553    13171.638850          2
# 24          299  1318683096           72.961     4959.114854          1
# 25          311    44227550           72.889     7006.580419          2
# 26          323      710960           65.152      986.147879          4
# 27          335    64606759           46.462      277.551859          4
# 28          347     3800610           55.322     3632.557798          4
# 29          359     4133884           78.782     9645.061420          2
# 30          371    18013409           48.328     1544.750112          4
# 31          383     4493312           75.748    14619.222720          3
# 32          395    11416987           78.273     8948.102923          2
# 33          407    10228744           76.486    22833.308510          3
# 34          419     5468120           78.332    35278.418740          3
# 35          431      496374           54.791     2082.481567          4
# 36          443     9319622           72.235     6025.374752          2
# 37          455    13755680           74.994     6873.262326          2
# 38          467    80264543           71.338     5581.180998          4
# 39          479     6939688           71.878     5728.353514          2
# 40          491      551201           51.579    12154.089750          4
# 41          503     4906585           58.040      641.369524          4
# 42          515    76511887           52.947      690.805576          4
# 43          527     5238460           79.313    33207.084400          3
# 44          539    61083916           80.657    30470.016700          3
# 45          551     1454867           56.735    13206.484520          4
# 46          563     1688359           59.448      752.749726          4
# 115        1391     2009245           77.926    25768.257590          3
# 116        1403     9118773           48.159      926.141068          4
# 117        1415    43997828           49.339     9269.657808          4
# 118        1427    40448191           80.941    28821.063700          3
# 119        1439    20378239           72.396     3970.095407          1
# 120        1451    42292929           58.556     2602.394995          4
# 121        1463     1133066           39.613     4513.480643          4
# 122        1475     9031088           80.884    33859.748350          3
# 123        1487     7554661           81.701    37506.419070          3
# 124        1499    19314747           74.143     4184.548089          1
# 125        1511    23174294           78.400    28718.276840          1
# 126        1523    38139640           52.517     1107.482182          4
# 127        1535    65068149           70.616     7458.396327          1
# 128        1547     5701579           58.420      882.969944          4
# 129        1559     1056608           69.819    18008.509240          2
# 130        1571    10276158           73.923     7092.923025          4
# 131        1583    71158647           71.777     8458.276384          3
# 132        1595    29170398           51.542     1056.380121          4
# 133        1607    60776238           79.425    33203.261280          3
# 134        1619   301139947           78.242    42951.653090          2
# 135        1631     3447496           76.384    10611.462990          2
# 136        1643    26084662           73.747    11415.805690          2
# 137        1655    85262356           74.249     2441.576404          1
# 138        1667     4018332           73.422     3025.349798          1
# 139        1679    22211743           62.698     2280.769906          1
# 140        1691    11746035           42.384     1271.211593          4
# 141        1703    12311143           43.487      469.709298          4
# Dataset has been imported!
# Welcome to my menu. Select an option (1,2,3,4,5):
# 2
# Select 1 to query by row number or 2 to query by row name:
# 1
# Select the row number to query (indexes start in 0):
# 121
# country id         1.463000e+03
# population         1.133066e+06
# life_expectancy    3.961300e+01
# gdp_per_capita     4.513481e+03
# continent          4.000000e+00
# Name: 121, dtype: float64
# None
# Welcome to my menu. Select an option (1,2,3,4,5):
# 2
# Select 1 to query by row number or 2 to query by row name:
# 2
# Select the row number to query:
# potato
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d1e34d6b0e64> in <module>()
#      42             elif rowmethod == 2:
#      43                 print('Select the row number to query:')
# ---> 44                 rownumber = int(input())
#      45                 while rownumber not in data['country id'].values:
#      46
#
# ValueError: invalid literal for int() with base 10: 'potato'

# %% [markdown]
# **Once again, you didn't check if the entry was an integer and thus your code crashed!**

# %%
## Use this cell to create the "main" part of your program
## Use this cell to create the "main" part of your program
print('Welcome to Sana Hayee AND 0917966 business case.')

options = []
newdata = []

x = True

while x:
    print('Welcome to my menu. Select an option (1,2,3,4,5):')
    x = input()
    options.append(x)
    
    if x == '1':
        data = option1('countries.csv')
        #option2(data,2,107)
        print(data)
        print ('Dataset has been imported!')   
    elif x == '2':
        if '1' in options:
            
            print('Select 1 to query by row number or 2 to query by row name:')
            rowmethod = int(input())
            while rowmethod not in [1,2]:
            
                    print('Option not valid')
                    print('Select 1 to query by row number or 2 to query by row name:')
                    rowmethod = int(input())
                    continue 
            
            if rowmethod == 1:
                print('Select the row number to query (indexes start in 0):')
                rownumber = int(input())
                while rownumber < 0 or rownumber > len(data):
            
                    print('Option not valid')
                    print('Select the row number to query (indexes start in 0):')
                    rownumber = int(input())
                    continue 
            
            elif rowmethod == 2:
                print('Select the row number to query:')
                rownumber = int(input())
                while rownumber not in data['country id'].values:
            
                    print('Option not valid')
                    print('Select the row number to query:')
                    rownumber = int(input())
                    continue 
                    
            rowdata = option2 (data, rowmethod, rownumber)
            print(rowdata)
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '3':
        if '1' in options:
            y = True
            while y:
                print('Indicate a column to include:')
                print(data.columns)
                columnname = input()
                if columnname not in data:
                    print('Column does not exists')
                    continue  
                        
                       
                #columnname = 'population'
                option3(columnname,data,newdata)
                print('Do you want to indicate another column? (Y/N)')           
                yn = input()
                if yn == 'N' or yn == 'n':
                    print(newdata)
                    break
                                
            
        else:
            print('The first option to be selected shall be 1. Please try again')
        # (students, marks) = option3()
    elif x == '4':
        if '1' in options:
            z = True
            xaxis = ''
            yaxis = ''
            while z:
                print('Select the variable to use as x axis:')
                print(data.columns)
                xaxis=input()
                while xaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as x axis:')
                    print(data.columns)
                    xaxis=input()
                    continue 
            
                print('Select the variable to use as y axis:')
                print(data.columns)
                yaxis=input()
                while yaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as y axis:')
                    print(data.columns)
                    yaxis=input()
                    continue 
                
                print('Select the variable to use as target:')
                print(data.columns)
                target=input()
                while target not in data:
                    print('Column does not exists')
                    print('Select the variable to use as target:')
                    print(data.columns)
                    target=input()
                    continue 
                    
                option4(xaxis,yaxis,target)
                break
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '5':
        
       
        break
    else:
        print('Wrong option. Please try again.')
# Out:
# Welcome to Sana Hayee AND 0917966 business case.
# Welcome to my menu. Select an option (1,2,3,4,5):
# 1
#      country id  population  life_expectancy  gdp_per_capita  continent
# 0            11    31889923           43.828      974.580338          1
# 1            23     3600523           76.423     5937.029526          3
# 2            35    33333216           72.301     6223.367465          4
# 3            47    12420476           42.731     4797.231267          4
# 4            59    40301927           75.320    12779.379640          2
# 5            71    20434176           81.235    34435.367440          5
# 6            83     8199783           79.829    36126.492700          3
# 7            95      708573           75.635    29796.048340          1
# 8           107   150448339           64.062     1391.253792          1
# 9           119    10392226           79.441    33692.605080          3
# 10          131     8078314           56.728     1441.284873          4
# 11          143     9119152           65.554     3822.137084          2
# 12          155     4552198           74.852     7446.298803          3
# 13          167     1639131           50.728    12569.851770          4
# 14          179   190010647           72.390     9065.800825          2
# 15          191     7322858           73.005    10680.792820          3
# 16          203    14326203           52.295     1217.032994          4
# 17          215     8390505           49.580      430.070692          4
# 18          227    14131858           59.723     1713.778686          1
# 19          239    17696293           50.430     2042.095240          4
# 20          251    33390141           80.653    36319.235010          2
# 21          263     4369038           44.741      706.016537          4
# 22          275    10238807           50.651     1704.063724          4
# 23          287    16284741           78.553    13171.638850          2
# 24          299  1318683096           72.961     4959.114854          1
# 25          311    44227550           72.889     7006.580419          2
# 26          323      710960           65.152      986.147879          4
# 27          335    64606759           46.462      277.551859          4
# 28          347     3800610           55.322     3632.557798          4
# 29          359     4133884           78.782     9645.061420          2
# 30          371    18013409           48.328     1544.750112          4
# 31          383     4493312           75.748    14619.222720          3
# 32          395    11416987           78.273     8948.102923          2
# 33          407    10228744           76.486    22833.308510          3
# 34          419     5468120           78.332    35278.418740          3
# 35          431      496374           54.791     2082.481567          4
# 36          443     9319622           72.235     6025.374752          2
# 37          455    13755680           74.994     6873.262326          2
# 106        1283    22276056           72.476    10808.475610          3
# 107        1295     8860588           46.242      863.088464          4
# 108        1307      199579           65.528     1598.435089          4
# 109        1319    27601038           72.777    21654.831940          1
# 110        1331    12267493           63.062     1712.472136          4
# 111        1343    10150265           74.002     9786.534714          3
# 112        1355     6144562           42.568      862.540756          4
# 113        1367     4553009           79.972    47143.179640          1
# 114        1379     5447502           74.663    18678.314350          3
# 115        1391     2009245           77.926    25768.257590          3
# 116        1403     9118773           48.159      926.141068          4
# 117        1415    43997828           49.339     9269.657808          4
# 118        1427    40448191           80.941    28821.063700          3
# 119        1439    20378239           72.396     3970.095407          1
# 120        1451    42292929           58.556     2602.394995          4
# 121        1463     1133066           39.613     4513.480643          4
# 122        1475     9031088           80.884    33859.748350          3
# 123        1487     7554661           81.701    37506.419070          3
# 124        1499    19314747           74.143     4184.548089          1
# 125        1511    23174294           78.400    28718.276840          1
# 126        1523    38139640           52.517     1107.482182          4
# 127        1535    65068149           70.616     7458.396327          1
# 128        1547     5701579           58.420      882.969944          4
# 129        1559     1056608           69.819    18008.509240          2
# 130        1571    10276158           73.923     7092.923025          4
# 131        1583    71158647           71.777     8458.276384          3
# 132        1595    29170398           51.542     1056.380121          4
# 133        1607    60776238           79.425    33203.261280          3
# 134        1619   301139947           78.242    42951.653090          2
# 135        1631     3447496           76.384    10611.462990          2
# 136        1643    26084662           73.747    11415.805690          2
# 137        1655    85262356           74.249     2441.576404          1
# 138        1667     4018332           73.422     3025.349798          1
# 139        1679    22211743           62.698     2280.769906          1
# 140        1691    11746035           42.384     1271.211593          4
# 141        1703    12311143           43.487      469.709298          4
# Dataset has been imported!
# Welcome to my menu. Select an option (1,2,3,4,5):
# 2
# Select 1 to query by row number or 2 to query by row name:
# 2
# Select the row number to query:
# 0
# Option not valid
# Select the row number to query:
# 50000
# Option not valid
# Select the row number to query:
# 1703
#      country id  population  life_expectancy  gdp_per_capita  continent
# 141        1703    12311143           43.487      469.709298          4
# None
# Welcome to my menu. Select an option (1,2,3,4,5):
# 3
# Indicate a column to include:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# ioajdoisj
# Column does not exists
# Indicate a column to include:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# 079709
# Column does not exists
# Indicate a column to include:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# country id
# Do you want to indicate another column? (Y/N)
# y
# Indicate a column to include:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# country id
# Do you want to indicate another column? (Y/N)
# potato
# Indicate a column to include:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# country is
# Column does not exists
# Indicate a column to include:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# country id
# Do you want to indicate another column? (Y/N)
# N
# [array([  11,   23,   35,   47,   59,   71,   83,   95,  107,  119,  131,
#         143,  155,  167,  179,  191,  203,  215,  227,  239,  251,  263,
#         275,  287,  299,  311,  323,  335,  347,  359,  371,  383,  395,
#         407,  419,  431,  443,  455,  467,  479,  491,  503,  515,  527,
#         539,  551,  563,  575,  587,  599,  611,  623,  635,  647,  659,
#         671,  683,  695,  707,  719,  731,  743,  755,  767,  779,  791,
#         803,  815,  827,  839,  851,  863,  875,  887,  899,  911,  923,
#         935,  947,  959,  971,  983,  995, 1007, 1019, 1031, 1043, 1055,
#        1067, 1079, 1091, 1103, 1115, 1127, 1139, 1151, 1163, 1175, 1187,
#         803,  815,  827,  839,  851,  863,  875,  887,  899,  911,  923,
#         935,  947,  959,  971,  983,  995, 1007, 1019, 1031, 1043, 1055,
#        1067, 1079, 1091, 1103, 1115, 1127, 1139, 1151, 1163, 1175, 1187,
#        1199, 1211, 1223, 1235, 1247, 1259, 1271, 1283, 1295, 1307, 1319,
#        1331, 1343, 1355, 1367, 1379, 1391, 1403, 1415, 1427, 1439, 1451,
#        1463, 1475, 1487, 1499, 1511, 1523, 1535, 1547, 1559, 1571, 1583,
#        1595, 1607, 1619, 1631, 1643, 1655, 1667, 1679, 1691, 1703],
#       dtype=int64), array([  11,   23,   35,   47,   59,   71,   83,   95,  107,  119,  131,
#         143,  155,  167,  179,  191,  203,  215,  227,  239,  251,  263,
#         275,  287,  299,  311,  323,  335,  347,  359,  371,  383,  395,
#         407,  419,  431,  443,  455,  467,  479,  491,  503,  515,  527,
#         539,  551,  563,  575,  587,  599,  611,  623,  635,  647,  659,
#         671,  683,  695,  707,  719,  731,  743,  755,  767,  779,  791,
#         803,  815,  827,  839,  851,  863,  875,  887,  899,  911,  923,
#         935,  947,  959,  971,  983,  995, 1007, 1019, 1031, 1043, 1055,
#        1067, 1079, 1091, 1103, 1115, 1127, 1139, 1151, 1163, 1175, 1187,
#        1199, 1211, 1223, 1235, 1247, 1259, 1271, 1283, 1295, 1307, 1319,
#        1331, 1343, 1355, 1367, 1379, 1391, 1403, 1415, 1427, 1439, 1451,
#        1463, 1475, 1487, 1499, 1511, 1523, 1535, 1547, 1559, 1571, 1583,
#        1595, 1607, 1619, 1631, 1643, 1655, 1667, 1679, 1691, 1703],
#       dtype=int64), array([  11,   23,   35,   47,   59,   71,   83,   95,  107,  119,  131,
#         143,  155,  167,  179,  191,  203,  215,  227,  239,  251,  263,
#         275,  287,  299,  311,  323,  335,  347,  359,  371,  383,  395,
#         407,  419,  431,  443,  455,  467,  479,  491,  503,  515,  527,
#         539,  551,  563,  575,  587,  599,  611,  623,  635,  647,  659,
#         671,  683,  695,  707,  719,  731,  743,  755,  767,  779,  791,
#         803,  815,  827,  839,  851,  863,  875,  887,  899,  911,  923,
#         935,  947,  959,  971,  983,  995, 1007, 1019, 1031, 1043, 1055,
#        1067, 1079, 1091, 1103, 1115, 1127, 1139, 1151, 1163, 1175, 1187,
#        1199, 1211, 1223, 1235, 1247, 1259, 1271, 1283, 1295, 1307, 1319,
#        1331, 1343, 1355, 1367, 1379, 1391, 1403, 1415, 1427, 1439, 1451,
#        1463, 1475, 1487, 1499, 1511, 1523, 1535, 1547, 1559, 1571, 1583,
#        1595, 1607, 1619, 1631, 1643, 1655, 1667, 1679, 1691, 1703],
#       dtype=int64)] <class 'list'>

# %% [markdown]
# **The two cells above imply three problems:**
#     **1. If I input `potato` instead of yes, the program still asks me for more columns.**
#     **2. If I indicate a column that I indicated before, then the program allows me to include it in the `newdata` variable.**
#     **3. The newdata structure that you created is a list, which is not effective in case that we want to continue using this new structure.**

# %%
## Use this cell to create the "main" part of your program
## Use this cell to create the "main" part of your program
print('Welcome to Sana Hayee AND 0917966 business case.')

options = []
newdata = []

x = True

while x:
    print('Welcome to my menu. Select an option (1,2,3,4,5):')
    x = input()
    options.append(x)
    
    if x == '1':
        data = option1('countries.csv')
        #option2(data,2,107)
        print(data)
        print ('Dataset has been imported!')   
    elif x == '2':
        if '1' in options:
            
            print('Select 1 to query by row number or 2 to query by row name:')
            rowmethod = int(input())
            while rowmethod not in [1,2]:
            
                    print('Option not valid')
                    print('Select 1 to query by row number or 2 to query by row name:')
                    rowmethod = int(input())
                    continue 
            
            if rowmethod == 1:
                print('Select the row number to query (indexes start in 0):')
                rownumber = int(input())
                while rownumber < 0 or rownumber > len(data):
            
                    print('Option not valid')
                    print('Select the row number to query (indexes start in 0):')
                    rownumber = int(input())
                    continue 
            
            elif rowmethod == 2:
                print('Select the row number to query:')
                rownumber = int(input())
                while rownumber not in data['country id'].values:
            
                    print('Option not valid')
                    print('Select the row number to query:')
                    rownumber = int(input())
                    continue 
                    
            rowdata = option2 (data, rowmethod, rownumber)
            print(rowdata)
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '3':
        if '1' in options:
            y = True
            while y:
                print('Indicate a column to include:')
                print(data.columns)
                columnname = input()
                if columnname not in data:
                    print('Column does not exists')
                    continue  
                        
                       
                #columnname = 'population'
                option3(columnname,data,newdata)
                print('Do you want to indicate another column? (Y/N)')           
                yn = input()
                if yn == 'N' or yn == 'n':
                    print(newdata)
                    break
                                
            
        else:
            print('The first option to be selected shall be 1. Please try again')
        # (students, marks) = option3()
    elif x == '4':
        if '1' in options:
            z = True
            xaxis = ''
            yaxis = ''
            while z:
                print('Select the variable to use as x axis:')
                print(data.columns)
                xaxis=input()
                while xaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as x axis:')
                    print(data.columns)
                    xaxis=input()
                    continue 
            
                print('Select the variable to use as y axis:')
                print(data.columns)
                yaxis=input()
                while yaxis not in data:
                    print('Column does not exists')
                    print('Select the variable to use as y axis:')
                    print(data.columns)
                    yaxis=input()
                    continue 
                
                print('Select the variable to use as target:')
                print(data.columns)
                target=input()
                while target not in data:
                    print('Column does not exists')
                    print('Select the variable to use as target:')
                    print(data.columns)
                    target=input()
                    continue 
                    
                option4(xaxis,yaxis,target)
                break
        else:
            print('The first option to be selected shall be 1. Please try again')
    elif x == '5':
        
       
        break
    else:
        print('Wrong option. Please try again.')
# Out:
# Welcome to Sana Hayee AND 0917966 business case.
# Welcome to my menu. Select an option (1,2,3,4,5):
# 1
#      country id  population  life_expectancy  gdp_per_capita  continent
# 0            11    31889923           43.828      974.580338          1
# 1            23     3600523           76.423     5937.029526          3
# 2            35    33333216           72.301     6223.367465          4
# 3            47    12420476           42.731     4797.231267          4
# 4            59    40301927           75.320    12779.379640          2
# 5            71    20434176           81.235    34435.367440          5
# 6            83     8199783           79.829    36126.492700          3
# 7            95      708573           75.635    29796.048340          1
# 8           107   150448339           64.062     1391.253792          1
# 9           119    10392226           79.441    33692.605080          3
# 10          131     8078314           56.728     1441.284873          4
# 11          143     9119152           65.554     3822.137084          2

# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# gdp_per_capita
# Select the variable to use as target:
# Index(['country id', 'population', 'life_expectancy', 'gdp_per_capita',
#        'continent'],
#       dtype='object')
# continent
# Welcome to my menu. Select an option (1,2,3,4,5):
# 5

# %% [markdown]
# **The chart is missing the x-axis label**

# %% [markdown]
# ## Questions
# Please answer the following questions to appraise your level of engagement with the content of the course. Use the Markdown cell corresponding to each question to write your answers.

# %% [markdown]
# 1. Is there any other data structure or module in Python (besides *numpy*) which would allow you to import a *.csv* file in a more practical and manageable way? Use a code cell to support your answer.

# %% [markdown]
# **ANSWER:**

# %% [markdown]
# ## Use this cell to import your dataset with a data structure other than numpy
#
# option1
#
# Pandas can be used to import dataset with a data structure other than numpy. Following steps can
# be used to import and run.
# 1) import Pandas as pd
# 2) capture the file path. File path contains file name and file extention
# 3) run the code pd.read_csv
# 4) selecting subset of coloumns (you can select exact coloumns names to get an output). If specified
# coloumn name is different from csv file coloumn name. It will give NaN values message.
#
# option2
#
# Below cell also shows how to import data as a numpy.

# %%
#Option 1
#importing data with pandas
pd.read_csv('countries.csv')
# Out:
#      country id  population  life_expectancy  gdp_per_capita  continent
# 0            11    31889923           43.828      974.580338          1
# 1            23     3600523           76.423     5937.029526          3
# 2            35    33333216           72.301     6223.367465          4
# 3            47    12420476           42.731     4797.231267          4
# 4            59    40301927           75.320    12779.379640          2
# 5            71    20434176           81.235    34435.367440          5
# 6            83     8199783           79.829    36126.492700          3
# 7            95      708573           75.635    29796.048340          1
# 8           107   150448339           64.062     1391.253792          1
# 9           119    10392226           79.441    33692.605080          3
# 10          131     8078314           56.728     1441.284873          4
# 11          143     9119152           65.554     3822.137084          2
# 12          155     4552198           74.852     7446.298803          3
# 13          167     1639131           50.728    12569.851770          4
# 14          179   190010647           72.390     9065.800825          2
# 15          191     7322858           73.005    10680.792820          3
# 16          203    14326203           52.295     1217.032994          4
# 17          215     8390505           49.580      430.070692          4
# 18          227    14131858           59.723     1713.778686          1
# 19          239    17696293           50.430     2042.095240          4
# 20          251    33390141           80.653    36319.235010          2
# 21          263     4369038           44.741      706.016537          4
# 22          275    10238807           50.651     1704.063724          4
# 23          287    16284741           78.553    13171.638850          2
# 24          299  1318683096           72.961     4959.114854          1
# 25          311    44227550           72.889     7006.580419          2
# 26          323      710960           65.152      986.147879          4
# 27          335    64606759           46.462      277.551859          4
# 28          347     3800610           55.322     3632.557798          4
# 29          359     4133884           78.782     9645.061420          2
# 30          371    18013409           48.328     1544.750112          4
# 31          383     4493312           75.748    14619.222720          3
# 32          395    11416987           78.273     8948.102923          2
# 33          407    10228744           76.486    22833.308510          3
# 34          419     5468120           78.332    35278.418740          3
# 35          431      496374           54.791     2082.481567          4
# 36          443     9319622           72.235     6025.374752          2
# 37          455    13755680           74.994     6873.262326          2
# 38          467    80264543           71.338     5581.180998          4
# 39          479     6939688           71.878     5728.353514          2
# 40          491      551201           51.579    12154.089750          4
# 41          503     4906585           58.040      641.369524          4
# 42          515    76511887           52.947      690.805576          4
# 43          527     5238460           79.313    33207.084400          3
# 44          539    61083916           80.657    30470.016700          3
# 112        1355     6144562           42.568      862.540756          4
# 113        1367     4553009           79.972    47143.179640          1
# 114        1379     5447502           74.663    18678.314350          3
# 115        1391     2009245           77.926    25768.257590          3
# 116        1403     9118773           48.159      926.141068          4
# 117        1415    43997828           49.339     9269.657808          4
# 118        1427    40448191           80.941    28821.063700          3
# 119        1439    20378239           72.396     3970.095407          1
# 120        1451    42292929           58.556     2602.394995          4
# 121        1463     1133066           39.613     4513.480643          4
# 122        1475     9031088           80.884    33859.748350          3
# 123        1487     7554661           81.701    37506.419070          3
# 124        1499    19314747           74.143     4184.548089          1
# 125        1511    23174294           78.400    28718.276840          1
# 126        1523    38139640           52.517     1107.482182          4
# 127        1535    65068149           70.616     7458.396327          1
# 128        1547     5701579           58.420      882.969944          4
# 129        1559     1056608           69.819    18008.509240          2
# 130        1571    10276158           73.923     7092.923025          4
# 131        1583    71158647           71.777     8458.276384          3
# 132        1595    29170398           51.542     1056.380121          4
# 133        1607    60776238           79.425    33203.261280          3
# 134        1619   301139947           78.242    42951.653090          2
# 135        1631     3447496           76.384    10611.462990          2
# 136        1643    26084662           73.747    11415.805690          2
# 137        1655    85262356           74.249     2441.576404          1
# 138        1667     4018332           73.422     3025.349798          1
# 139        1679    22211743           62.698     2280.769906          1
# 140        1691    11746035           42.384     1271.211593          4
# 141        1703    12311143           43.487      469.709298          4

# %%
#Option 2
#importing data in numpy
countries=np.genfromtxt("countries.csv", delimiter =",", names = True, skip_header=0)
print(countries.dtype.names)
print(countries)
# Out:
# ('country_id', 'population', 'life_expectancy', 'gdp_per_capita', 'continent')
# [(  11., 3.18899230e+07, 43.828,   974.5803384, 1.)
#  (  23., 3.60052300e+06, 76.423,  5937.029526 , 3.)
#  (  35., 3.33332160e+07, 72.301,  6223.367465 , 4.)
#  (  47., 1.24204760e+07, 42.731,  4797.231267 , 4.)
#  (  59., 4.03019270e+07, 75.32 , 12779.37964  , 2.)
#  (  71., 2.04341760e+07, 81.235, 34435.36744  , 5.)
#  (  83., 8.19978300e+06, 79.829, 36126.4927   , 3.)
#  (  95., 7.08573000e+05, 75.635, 29796.04834  , 1.)
#  ( 107., 1.50448339e+08, 64.062,  1391.253792 , 1.)
#  ( 119., 1.03922260e+07, 79.441, 33692.60508  , 3.)
#  ( 131., 8.07831400e+06, 56.728,  1441.284873 , 4.)
#  ( 143., 9.11915200e+06, 65.554,  3822.137084 , 2.)
#  ( 155., 4.55219800e+06, 74.852,  7446.298803 , 3.)
#  ( 167., 1.63913100e+06, 50.728, 12569.85177  , 4.)
#  ( 179., 1.90010647e+08, 72.39 ,  9065.800825 , 2.)
#  ( 191., 7.32285800e+06, 73.005, 10680.79282  , 3.)
#  ( 203., 1.43262030e+07, 52.295,  1217.032994 , 4.)
#  ( 215., 8.39050500e+06, 49.58 ,   430.0706916, 4.)
#  ( 227., 1.41318580e+07, 59.723,  1713.778686 , 1.)
#  ( 239., 1.76962930e+07, 50.43 ,  2042.09524  , 4.)
#  ( 251., 3.33901410e+07, 80.653, 36319.23501  , 2.)
#  (1307., 1.99579000e+05, 65.528,  1598.435089 , 4.)
#  (1319., 2.76010380e+07, 72.777, 21654.83194  , 1.)
#  (1331., 1.22674930e+07, 63.062,  1712.472136 , 4.)
#  (1343., 1.01502650e+07, 74.002,  9786.534714 , 3.)
#  (1355., 6.14456200e+06, 42.568,   862.5407561, 4.)
#  (1367., 4.55300900e+06, 79.972, 47143.17964  , 1.)
#  (1379., 5.44750200e+06, 74.663, 18678.31435  , 3.)
#  (1391., 2.00924500e+06, 77.926, 25768.25759  , 3.)
#  (1403., 9.11877300e+06, 48.159,   926.1410683, 4.)
#  (1415., 4.39978280e+07, 49.339,  9269.657808 , 4.)
#  (1427., 4.04481910e+07, 80.941, 28821.0637   , 3.)
#  (1439., 2.03782390e+07, 72.396,  3970.095407 , 1.)
#  (1451., 4.22929290e+07, 58.556,  2602.394995 , 4.)
#  (1463., 1.13306600e+06, 39.613,  4513.480643 , 4.)
#  (1475., 9.03108800e+06, 80.884, 33859.74835  , 3.)
#  (1487., 7.55466100e+06, 81.701, 37506.41907  , 3.)
#  (1499., 1.93147470e+07, 74.143,  4184.548089 , 1.)
#  (1511., 2.31742940e+07, 78.4  , 28718.27684  , 1.)
#  (1523., 3.81396400e+07, 52.517,  1107.482182 , 4.)
#  (1535., 6.50681490e+07, 70.616,  7458.396327 , 1.)
#  (1547., 5.70157900e+06, 58.42 ,   882.9699438, 4.)
#  (1559., 1.05660800e+06, 69.819, 18008.50924  , 2.)
#  (1571., 1.02761580e+07, 73.923,  7092.923025 , 4.)
#  (1583., 7.11586470e+07, 71.777,  8458.276384 , 3.)
#  (1595., 2.91703980e+07, 51.542,  1056.380121 , 4.)
#  (1607., 6.07762380e+07, 79.425, 33203.26128  , 3.)
#  (1619., 3.01139947e+08, 78.242, 42951.65309  , 2.)
#  (1631., 3.44749600e+06, 76.384, 10611.46299  , 2.)
#  (1643., 2.60846620e+07, 73.747, 11415.80569  , 2.)
#  (1655., 8.52623560e+07, 74.249,  2441.576404 , 1.)
#  (1667., 4.01833200e+06, 73.422,  3025.349798 , 1.)
#  (1679., 2.22117430e+07, 62.698,  2280.769906 , 1.)
#  (1691., 1.17460350e+07, 42.384,  1271.211593 , 4.)
#  (1703., 1.23111430e+07, 43.487,   469.7092981, 4.)]

# %% [markdown]
# 2. Using any of the two continuous variables of your dataset, using a cell code show an example of how a **linear regression** could be applied with your dataset to predict the values of future entries of data without target/class (you can implement linear regressions using existing Python modules). Moreover, discuss if there is any metric that can be used to decide which two variables are the most correlated.

# %% [markdown]
# **ANSWER:**

# %%
## Use this cell to implement a linear regression between two variables
#data.plot(kind='scatter', x='gdp_per_capita', y='population', c='continent', cmap='gnuplot2', title= 'GDP vs Population')

data=pd.read_csv('countries.csv')
#values converts it into a numpy array
X = data.iloc[:, 0].values.reshape(-1, 1)
#-1 means that calculate the dimension of rows, but have 1 column
Y = data.iloc[:, 1].values.reshape(-1, 1) 
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X) 
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()
